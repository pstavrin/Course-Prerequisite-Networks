# %%
import pandas as pd
import networkx as nx
import numpy as np
import random
import re

# %% [markdown]
# # **Construct Caltech, CUT and JHU CPNs**

# %% [markdown]
# ## Caltech

# %%
Caltech_data = pd.read_csv("2021-22-course-prereqs - clean.csv")
Caltech_data["Prereaquisites (clean)"] = Caltech_data["Prereaquisites (clean)"].fillna("")
Caltech_data
# Out:
#     department_name Acronym course_number   Node_name  \
# 0         Aerospace      Ae           100      Ae 100
# 1         Aerospace      Ae       101 abc  Ae 101 abc
# 2         Aerospace      Ae       102 abc  Ae 102 abc
# 3         Aerospace      Ae        103 ab   Ae 103 ab
# 4         Aerospace      Ae       104 abc  Ae 104 abc
# ..              ...     ...           ...         ...
# 766         Physics      Ph       236 abc  Ph 236 abc
# 767         Physics      Ph           237      Ph 237
# 768         Physics      Ph        242 ab   Ph 242 ab
# 769         Physics      Ph           250      Ph 250
# 770         Physics      Ph           300      Ph 300
#
#                            course_title  \
# 0                 Research in Aerospace
# 1                       Fluid Mechanics
# 2    Mechanics of Structures and Solids
# 3             Aerospace Control Systems
# 4                  Experimental Methods
# ..                                  ...
# 766                  General Relativity
# 767             Gravitational Radiation
# 768                     Physics Seminar
# 769       Introduction to String Theory
# 770                     Thesis Research
#
#                                          prerequisites  \
# 0                                                  NaN
# 1    APh 17 or ME 11 abc, and ME 12 or equivalent, ...
# 2                                            ME 12 abc
# 3    CDS 110 (or equivalent), CDS 131 or permission...
# 4    ACM 95/100 ab or equivalent (may be taken conc...
# ..                                                 ...
# 766  a mastery of special relativity at the level o...
# 767                   Ph 106 b, Ph 12 b or equivalents
# 768                                                NaN
# 769                               Ph 205 or equivalent
# 770                                                NaN
#
#                Prereaquisites (clean)
# 0
# 1    APh 17 abc, ME 11 abc, ME 12 abc
# 2                           ME 12 abc
# 3                    CDS 110, CDS 131
# 4           ACM 95/100 ab, Ae 101 abc
# ..                                ...
# 766
# 767             Ph 106 abc, Ph 12 abc
# 768
# 769                        Ph 205 abc
# 770
#
# [771 rows x 7 columns]

# %%
Caltech_node_list = Caltech_data["Node_name"].to_list()
Caltech_node_list
# Out:
# ['Ae 100',
#  'Ae 101 abc',
#  'Ae 102 abc',
#  'Ae 103 ab',
#  'Ae 104 abc',
#  'Ae 105 abc',
#  'Ae 115 ab',
#  'Ae 118',
#  'Ae 120',
#  'Ae 150 abc',
#  'Ae 159',
#  'Ae 160 ab',
#  'Ae 165 ab',
#  'Ae 200',
#  'Ae 201 a',
#  'Ae 204 ab',
#  'Ae 205 ab',
#  'Ae 208 abc',
#  'Ae 213',
#  'Ae 214',
#  'Ae 215',
#  'Ae 218',
#  'Ae 220',
#  'Ae 221',
#  'Ae 223',
#  'Ae 225',
#  'Ae 232 ab',
#  'Ae 233',
#  'Ae 234 ab',
#  'Ae 235',
#  'Ae 237 ab',
#  'Ae 239 ab',
#  'Ae 240',
#  'Ae 241',
#  'Ae 242',
#  'Ae 250',
#  'Ae 251 ab',
#  'Ae 265 ab',
#  'Ae 121 abc',
#  'ACM 11',
#  'ACM 80 abc',
#  'ACM 81 abc',
#  'ACM 95/100 ab',
#  'ACM 101 ab',
#  'ACM 104',
#  'ACM 105',
#  'ACM 106 ab',
#  'ACM 109',
#  'ACM 116',
#  'ACM 118',
#  'ACM 154',
#  'ACM 170',
#  'ACM 190',
#  'ACM 201',
#  'ACM 204',
#  'ACM 206',
#  'ACM 210',
#  'ACM 213',
#  'ACM 216',
#  'ACM 217',
#  'ACM 256',
#  'ACM 257',
#  'ACM 270',
#  'ACM 300',
#  'AM 127',
#  'AM 150 abc',
#  'AM 151',
#  'AM 165',
#  'AM 200',
#  'AM 201',
#  'AM 252',
#  'AM 300',
#  'APh 9 ab',
#  'APh 17 abc',
#  'APh 23',
#  'APh 24',
#  'APh 77 bc',
#  'APh 78 abc',
#  'APh 79 abc',
#  'APh 100',
#  'APh 105 abc',
#  'APh 109',
#  'APh 110',
#  'APh 112 ab',
#  'APh 114 abc',
#  'APh 115',
#  'APh 116',
#  'APh 130',
#  'APh 132',
#  'APh 138 ab',
#  'APh 150',
#  'APh 156 abc',
#  'APh 183',
#  'APh 190 abc',
#  'APh 200',
#  'APh 250',
#  'APh 256',
#  'APh 300',
#  'Ay 1',
#  'Ay 20',
#  'Ay 21',
#  'Ay 30',
#  'Ay 31',
#  'Ay 43',
#  'Ay 78 abc',
#  'Ay 101',
#  'Ay 102',
#  'Ay 104',
#  'Ay 105',
#  'Ay 107',
#  'Ay 111 ab',
#  'Ay 119',
#  'Ay 121',
#  'Ay 122 abc',
#  'Ay 123',
#  'Ay 124',
#  'Ay 125',
#  'Ay 126',
#  'Ay 127',
#  'Ay 141 abc',
#  'Ay 142',
#  'Ay 143',
#  'Ay 144',
#  'Ay 190',
#  'Ay 198',
#  'Ay 211',
#  'Ay 215',
#  'Ay 218',
#  'Ay 219',
#  'BMB 170',
#  'BMB 173',
#  'BMB 174',
#  'BMB 178',
#  'BMB 202 abc',
#  'BMB 230',
#  'BMB 278',
#  'BMB 299',
#  'BE 1',
#  'BE 25',
#  'BE 98',
#  'BE 99 abc',
#  'BE 101',
#  'BE 103 a',
#  'BE 103 b',
#  'BE 106',
#  'BE 107',
#  'BE 150',
#  'BE 153',
#  'BE 159',
#  'BE 161',
#  'BE 189 ab',
#  'BE 197',
#  'BE 200',
#  'BE 201',
#  'BE 203',
#  'BE 205',
#  'BE 240',
#  'BE 262',
#  'BE 267',
#  'BE 191 ab',
#  'BE 196 ab',
#  'Bi 1',
#  'Bi 1 x',
#  'Bi 2',
#  'Bi 8',
#  'Bi 9',
#  'Bi 10',
#  'Bi 21',
#  'Bi 22',
#  'Bi 23',
#  'Bi 24',
#  'Bi 90 abc',
#  'Bi 114',
#  'Bi 115',
#  'Bi 116',
#  'Bi 117',
#  'Bi 118',
#  'Bi 122',
#  'Bi 129',
#  'Bi 145 b',
#  'Bi 158',
#  'Bi 160',
#  'Bi 165',
#  'Bi 177',
#  'Bi 180',
#  'Bi 182',
#  'Bi 183',
#  'Bi 184',
#  'Bi 185',
#  'Bi 188',
#  'Bi 189',
#  'Bi 190',
#  'Bi 192',
#  'Bi 195',
#  'Bi 206',
#  'Bi 214',
#  'Bi 222',
#  'Bi 227',
#  'Bi 230',
#  'Bi 241',
#  'Bi 250 a',
#  'Bi 250 b',
#  'Bi 250 d',
#  'Bi 251 abc',
#  'Bi 252',
#  'Bi 270 abc',
#  'Bi 299',
#  'Bi 105',
#  'Bi 145 a',
#  'ChE 10',
#  'ChE 15',
#  'ChE 62',
#  'ChE 63 ab',
#  'ChE 70',
#  'ChE 80',
#  'ChE 90 abc',
#  'ChE 101',
#  'ChE 103 abc',
#  'ChE 105',
#  'ChE 107',
#  'ChE 111',
#  'ChE 112',
#  'ChE 114',
#  'ChE 115',
#  'ChE 118',
#  'ChE 120',
#  'ChE 126',
#  'ChE 128',
#  'ChE 130',
#  'ChE 141',
#  'ChE 142',
#  'ChE 148',
#  'ChE 151 ab',
#  'ChE 152',
#  'ChE 155',
#  'ChE 163',
#  'ChE 164',
#  'ChE 165',
#  'ChE 174',
#  'ChE 188',
#  'ChE 190',
#  'ChE 280',
#  'Ch 1 ab',
#  'Ch 3',
#  'Ch 3 x',
#  'Ch 6 ab',
#  'Ch 7',
#  'Ch 14',
#  'Ch 15',
#  'Ch 21 abc',
#  'Ch 25',
#  'Ch 41 abc',
#  'Ch 80',
#  'Ch 81',
#  'Ch 82',
#  'Ch 90',
#  'Ch 91',
#  'Ch 101',
#  'Ch 102',
#  'Ch 104',
#  'Ch 110',
#  'Ch 111',
#  'Ch 112',
#  'Ch 117',
#  'Ch 121 ab',
#  'Ch 122',
#  'Ch 125 ab',
#  'Ch 129',
#  'Ch 135',
#  'Ch 140 ab',
#  'Ch 143',
#  'Ch 145',
#  'Ch 146',
#  'Ch 147',
#  'Ch 149',
#  'Ch 153 abc',
#  'Ch 154 ab',
#  'Ch 180',
#  'Ch 212',
#  'Ch 213 abc',
#  'Ch 225',
#  'Ch 226',
#  'Ch 242 ab',
#  'Ch 247',
#  'Ch 250',
#  'Ch 251',
#  'Ch 252',
#  'Ch 253',
#  'Ch 279',
#  'Ch 280',
#  'Ch 4 ab',
#  'Ch 5 ab',
#  'Ch 8',
#  'Ch 9',
#  'Ch 10 abc',
#  'Ch 120 ab',
#  'Ch 144 ab',
#  'CE 90 abc',
#  'CE 100',
#  'CE 108 ab',
#  'CE 112 ab',
#  'CE 160 ab',
#  'CE 173',
#  'CE 180',
#  'CE 181 ab',
#  'CE 200',
#  'CE 201',
#  'CE 222',
#  'CE 300',
#  'CE 108',
#  'CNS 100',
#  'CNS 102 ab',
#  'CNS 131',
#  'CNS 176',
#  'CNS 180',
#  'CNS 186',
#  'CNS 187',
#  'CNS 247',
#  'CNS 251',
#  'CNS 256',
#  'CNS 280',
#  'CNS 286 abc',
#  'CS 1',
#  'CS 1 x',
#  'CS 3',
#  'CS 4',
#  'CS 9',
#  'CS 11',
#  'CS 12',
#  'CS 19 ab',
#  'CS 21',
#  'CS 22',
#  'CS 24',
#  'CS 38',
#  'CS 42',
#  'CS 75 abc',
#  'CS 80 abc',
#  'CS 81 abc',
#  'CS 90',
#  'CS 101',
#  'CS 102 abc',
#  'CS 103 abc',
#  'CS 111',
#  'CS 115',
#  'CS 116',
#  'CS 118',
#  'CS 120',
#  'CS 121',
#  'CS 122',
#  'CS 123',
#  'CS 124',
#  'CS 130',
#  'CS 132',
#  'CS 137',
#  'CS 138',
#  'CS 141',
#  'CS 143',
#  'CS 145',
#  'CS 146',
#  'CS 149',
#  'CS 151',
#  'CS 152',
#  'CS 153',
#  'CS 156 ab',
#  'CS 159',
#  'CS 165',
#  'CS 166',
#  'CS 171',
#  'CS 174',
#  'CS 177 a',
#  'CS 178',
#  'CS 179',
#  'CS 274 abc',
#  'CS 280',
#  'CS 282 abc',
#  'CS 286 abc',
#  'CS 287',
#  'CS 2',
#  'CS 131',
#  'CS 142',
#  'CS 150 ab',
#  'CS 162',
#  'CS 176',
#  'CS 180',
#  'CS 163',
#  'CMS 107',
#  'CMS 117',
#  'CMS 122',
#  'CMS 139',
#  'CMS 144',
#  'CMS 155',
#  'CMS 270',
#  'CMS 300',
#  'CMS 290 abc',
#  'CDS 90 abc',
#  'CDS 110',
#  'CDS 112',
#  'CDS 131',
#  'CDS 141',
#  'CDS 190',
#  'CDS 231',
#  'CDS 232',
#  'CDS 233',
#  'CDS 242',
#  'CDS 243',
#  'CDS 244',
#  'CDS 270',
#  'CDS 300 abc',
#  'EE 1',
#  'EE 7',
#  'EE 10 ab',
#  'EE 13',
#  'EE 40',
#  'EE 44',
#  'EE 45',
#  'EE 55',
#  'EE 80 abc',
#  'EE 85',
#  'EE 90',
#  'EE 91',
#  'EE 99',
#  'EE 105 abc',
#  'EE 110 abc',
#  'EE 111',
#  'EE 112',
#  'EE 113',
#  'EE 114 ab',
#  'EE 115',
#  'EE 119 abc',
#  'EE 120',
#  'EE 121',
#  'EE 123',
#  'EE 125',
#  'EE 126 ab',
#  'EE 127',
#  'EE 128 ab',
#  'EE 131',
#  'EE 135',
#  'EE 136',
#  'EE 147',
#  'EE 148',
#  'EE 149',
#  'EE 150',
#  'EE 151',
#  'EE 153',
#  'EE 154 ab',
#  'EE 157 ab',
#  'EE 158',
#  'EE 160',
#  'EE 161',
#  'EE 163',
#  'EE 164',
#  'EE 167',
#  'EE 175',
#  'EE 180',
#  'EE 185',
#  'EE 187',
#  'EE 291',
#  'EE 124',
#  'EE 152',
#  'EE 2',
#  'E 2',
#  'E 88',
#  'E 89',
#  'E 100',
#  'E 102',
#  'E 103',
#  'E 105 ab',
#  'E 110',
#  'ESE 1',
#  'ESE 90',
#  'ESE 91',
#  'ESE 100',
#  'ESE 101',
#  'ESE 102',
#  'ESE 103',
#  'ESE 104',
#  'ESE 106',
#  'ESE 110 abc',
#  'ESE 130',
#  'ESE 131',
#  'ESE 132',
#  'ESE 133',
#  'ESE 134',
#  'ESE 135',
#  'ESE 136',
#  'ESE 137',
#  'ESE 138',
#  'ESE 142',
#  'ESE 144',
#  'ESE 156',
#  'ESE 158',
#  'ESE 168',
#  'ESE 171',
#  'ESE 172',
#  'ESE 176',
#  'ESE 177',
#  'ESE 179',
#  'ESE 200',
#  'ESE 300',
#  'ESE 166',
#  'Ge 1',
#  'Ge 10',
#  'Ge 11 a',
#  'Ge 11 b',
#  'Ge 11 c',
#  'Ge 11 d',
#  'Ge 40',
#  'Ge 41 abc',
#  'Ge 101',
#  'Ge 102',
#  'Ge 103',
#  'Ge 104',
#  'Ge 106',
#  'Ge 108',
#  'Ge 109',
#  'Ge 112',
#  'Ge 114 a',
#  'Ge 114 b',
#  'Ge 115 a',
#  'Ge 115 b',
#  'Ge 115 c',
#  'Ge 116',
#  'Ge 117',
#  'Ge 118',
#  'Ge 119',
#  'Ge 120 a',
#  'Ge 120 b',
#  'Ge 121 abc',
#  'Ge 122 abc',
#  'Ge 123',
#  'Ge 124 a',
#  'Ge 124 b',
#  'Ge 125',
#  'Ge 126',
#  'Ge 127',
#  'Ge 128',
#  'Ge 131',
#  'Ge 132',
#  'Ge 133',
#  'Ge 136 abc',
#  'Ge 137',
#  'Ge 139',
#  'Ge 140 a',
#  'Ge 140 b',
#  'Ge 140 c',
#  'Ge 141',
#  'Ge 143',
#  'Ge 145',
#  'Ge 147',
#  'Ge 149',
#  'Ge 150',
#  'Ge 151',
#  'Ge 154',
#  'Ge 155',
#  'Ge 156',
#  'Ge 157 c',
#  'Ge 159',
#  'Ge 161',
#  'Ge 162',
#  'Ge 163',
#  'Ge 164',
#  'Ge 165',
#  'Ge 166',
#  'Ge 167',
#  'Ge 169 abcd',
#  'Ge 177',
#  'Ge 178',
#  'Ge 190',
#  'Ge 191',
#  'Ge 192',
#  'Ge 193',
#  'Ge 194',
#  'Ge 195',
#  'Ge 196',
#  'Ge 197',
#  'Ge 211',
#  'Ge 212',
#  'Ge 214',
#  'Ge 215',
#  'Ge 217',
#  'Ge 218',
#  'Ge 219',
#  'Ge 244',
#  'Ge 246',
#  'Ge 248',
#  'Ge 261',
#  'Ge 263',
#  'Ge 264',
#  'Ge 270',
#  'Ge 271',
#  'Ge 277',
#  'Ge 298',
#  'Ge 111 ab',
#  'IDS 9',
#  'IDS 126',
#  'IDS 157',
#  'IDS 158',
#  'IDS 197',
#  'IDS 198',
#  'IDS 199',
#  'MS 78 abc',
#  'MS 90',
#  'MS 100',
#  'MS 110 abc',
#  'MS 115',
#  'MS 116',
#  'MS 121',
#  'MS 122',
#  'MS 125',
#  'MS 131',
#  'MS 132',
#  'MS 133',
#  'MS 141',
#  'MS 142',
#  'MS 150 abc',
#  'MS 161',
#  'MS 162',
#  'MS 166',
#  'MS 171',
#  'MS 200',
#  'MS 300',
#  'Ma 1 abc',
#  'Ma 1 d',
#  'Ma 2/102',
#  'Ma 3/103',
#  'Ma 4/104',
#  'Ma 5/105 abc',
#  'Ma 6/106 abc',
#  'Ma 7/107',
#  'Ma 8',
#  'Ma 10',
#  'Ma 13',
#  'Ma 17',
#  'Ma 20',
#  'Ma 92 abc',
#  'Ma 97',
#  'Ma 98',
#  'Ma 108 abc',
#  'Ma 109 abc',
#  'Ma 110 abc',
#  'Ma 111 abc',
#  'Ma 112 ab',
#  'Ma 116 abc',
#  'Ma 117 abc',
#  'Ma 118',
#  'Ma 120 abc',
#  'Ma 121 ab',
#  'Ma 123',
#  'Ma 124',
#  'Ma 125',
#  'Ma 128',
#  'Ma 130 abc',
#  'Ma 132 abc',
#  'Ma 135 ab',
#  'Ma 140 ab',
#  'Ma 142 ab',
#  'Ma 145 abc',
#  'Ma 147 abc',
#  'Ma 148 ab',
#  'Ma 151 abc',
#  'Ma 157 abc',
#  'Ma 160 abc',
#  'Ma 162 ab',
#  'Ma 191 abc',
#  'Ma 290',
#  'Ma 11',
#  'Ma 390',
#  'ME 8',
#  'ME 10',
#  'ME 11 abc',
#  'ME 12 abc',
#  'ME 13/113',
#  'ME 14',
#  'ME 23/123',
#  'ME 40',
#  'ME 50 ab',
#  'ME 72 ab',
#  'ME 90 abc',
#  'ME 100',
#  'ME 110',
#  'ME 115 ab',
#  'ME 117',
#  'ME 119',
#  'ME 129',
#  'ME 133 abc',
#  'ME 146',
#  'ME 163',
#  'ME 169',
#  'ME 174',
#  'ME 200',
#  'ME 201',
#  'ME 202 abc',
#  'ME 224',
#  'ME 234 ab',
#  'ME 260',
#  'ME 266 ab',
#  'ME 300',
#  'ME 134',
#  'MedE 99',
#  'MedE 100 abc',
#  'MedE 101',
#  'MedE 168 abc',
#  'MedE 199',
#  'MedE 201 ab',
#  'MedE 202',
#  'MedE 205',
#  'MedE 243',
#  'MedE 268',
#  'MedE 291',
#  'NB 150',
#  'NB 152',
#  'NB 154',
#  'NB 155',
#  'NB 157',
#  'NB 162',
#  'NB 163',
#  'NB 164',
#  'NB 216',
#  'NB 217',
#  'NB 220',
#  'NB 250 c',
#  'NB 299',
#  'Ph 1 abc',
#  'Ph 2 abc',
#  'Ph 3',
#  'Ph 5',
#  'Ph 6',
#  'Ph 7',
#  'Ph 8 bc',
#  'Ph 10',
#  'Ph 12 abc',
#  'Ph 20',
#  'Ph 21',
#  'Ph 22',
#  'Ph 50 ab',
#  'Ph 70',
#  'Ph 77 abc',
#  'Ph 78 abc',
#  'Ph 79 abc',
#  'Ph 101',
#  'Ph 105',
#  'Ph 106 abc',
#  'Ph 118 ab',
#  'Ph 121 abc',
#  'Ph 125 abc',
#  'Ph 127 ab',
#  'Ph 129 abc',
#  'Ph 135',
#  'Ph 136 abc',
#  'Ph 137 abc',
#  'Ph 139',
#  'Ph 171',
#  'Ph 172',
#  'Ph 177',
#  'Ph 198',
#  'Ph 199',
#  'Ph 201',
#  'Ph 203',
#  'Ph 205 abc',
#  'Ph 219 abc',
#  'Ph 223 ab',
#  'Ph 229 abc',
#  'Ph 230 abc',
#  'Ph 232',
#  'Ph 235 ab',
#  'Ph 236 abc',
#  'Ph 237',
#  'Ph 242 ab',
#  'Ph 250',
#  'Ph 300']

# %%
Caltech_edge_list = []
for i in range(len(Caltech_node_list)):
  reqs = Caltech_data["Prereaquisites (clean)"][i]
  if reqs == "":
    continue
  splitted = reqs.split(",")
  cleaned = [string.lstrip() for string in splitted]
  for j in cleaned:
    Caltech_edge_list.append((j, Caltech_node_list[i]))

Caltech_edge_list
# Out:
# [('APh 17 abc', 'Ae 101 abc'),
#  ('ME 11 abc', 'Ae 101 abc'),
#  ('ME 12 abc', 'Ae 101 abc'),
#  ('ME 12 abc', 'Ae 102 abc'),
#  ('CDS 110', 'Ae 103 ab'),
#  ('CDS 131', 'Ae 103 ab'),
#  ('ACM 95/100 ab', 'Ae 104 abc'),
#  ('Ae 101 abc', 'Ae 104 abc'),
#  ('ME 11 abc', 'Ae 105 abc'),
#  ('ME 12 abc', 'Ae 105 abc'),
#  ('CDS 110', 'Ae 115 ab'),
#  ('ME 11 abc', 'Ae 118'),
#  ('ME 12 abc', 'Ae 118'),
#  ('Ae 118', 'Ae 120'),
#  ('ME 119', 'Ae 120'),
#  ('Ph 2 abc', 'Ae 159'),
#  ('EE 157 ab', 'Ae 159'),
#  ('APh 23', 'Ae 159'),
#  ('Ae 102 abc', 'Ae 165 ab'),
#  ('Ae 101 abc', 'Ae 201 a'),
#  ('ACM 101 ab', 'Ae 201 a'),
#  ('Ae 101 abc', 'Ae 204 ab'),
#  ('Ae 105 abc', 'Ae 205 ab'),
#  ('Ae 102 abc', 'Ae 213'),
#  ('ACM 95/100 ab', 'Ae 214'),
#  ('Ae 102 abc', 'Ae 214'),
#  ('CE 108 ab', 'Ae 214'),
#  ('ACM 101 ab', 'Ae 215'),
#  ('Ae 102 abc', 'Ae 215'),
#  ('Ae 118', 'Ae 218'),
#  ('Ae 102 abc', 'Ae 220'),
#  ('Ae 102 abc', 'Ae 223'),
#  ('Ae 101 abc', 'Ae 232 ab'),
#  ('ACM 95/100 ab', 'Ae 232 ab'),
#  ('Ae 101 abc', 'Ae 233'),
#  ('Ae 101 abc', 'Ae 234 ab'),
#  ('ACM 95/100 ab', 'Ae 234 ab'),
#  ('Ae 101 abc', 'Ae 239 ab'),
#  ('ACM 101 ab', 'Ae 239 ab'),
#  ('Ae 104 abc', 'Ae 241'),
#  ('Ae 101 abc', 'Ae 242'),
#  ('ChE 103 abc', 'Ae 242'),
#  ('ACM 95/100 ab', 'Ae 251 ab'),
#  ('Ae 101 abc', 'Ae 251 ab'),
#  ('Ae 102 abc', 'Ae 265 ab'),
#  ('Ma 1 abc', 'ACM 11'),
#  ('CS 1', 'ACM 11'),
#  ('Ma 1 abc', 'ACM 95/100 ab'),
#  ('Ma 2/102', 'ACM 95/100 ab'),
#  ('Ma 2/102', 'ACM 101 ab'),
#  ('ACM 95/100 ab', 'ACM 101 ab'),
#  ('Ma 1 abc', 'ACM 104'),
#  ('ACM 11', 'ACM 104'),
#  ('Ma 2/102', 'ACM 105'),
#  ('Ma 108 abc', 'ACM 105'),
#  ('ACM 104', 'ACM 105'),
#  ('Ma 1 abc', 'ACM 106 ab'),
#  ('Ma 2/102', 'ACM 106 ab'),
#  ('Ma 3/103', 'ACM 106 ab'),
#  ('ACM 11', 'ACM 106 ab'),
#  ('ACM 95/100 ab', 'ACM 106 ab'),
#  ('ACM 95/100 ab', 'ACM 109'),
#  ('Ma 3/103', 'ACM 116'),
#  ('EE 55', 'ACM 116'),
#  ('ACM 11', 'ACM 116'),
#  ('CMS 107', 'ACM 118'),
#  ('CMS 117', 'ACM 118'),
#  ('ACM 104', 'ACM 154'),
#  ('ACM 106 ab', 'ACM 154'),
#  ('ACM 116', 'ACM 154'),
#  ('IDS 157', 'ACM 154'),
#  ('ACM 104', 'ACM 170'),
#  ('CMS 122', 'ACM 170'),
#  ('ACM 116', 'ACM 170'),
#  ('ACM 95/100 ab', 'ACM 201'),
#  ('ACM 101 ab', 'ACM 201'),
#  ('ACM 11', 'ACM 201'),
#  ('CMS 107', 'ACM 204'),
#  ('ACM 106 ab', 'ACM 206'),
#  ('ACM 11', 'ACM 210'),
#  ('ACM 106 ab', 'ACM 210'),
#  ('ACM 104', 'ACM 213'),
#  ('CMS 122', 'ACM 213'),
#  ('ACM 116', 'ACM 216'),
#  ('CMS 117', 'ACM 217'),
#  ('ACM 101 ab', 'ACM 256'),
#  ('ACM 95/100 ab', 'ACM 257'),
#  ('ACM 95/100 ab', 'AM 127'),
#  ('Ae 160 ab', 'AM 165'),
#  ('Ma 1 abc', 'APh 17 abc'),
#  ('Ph 1 abc', 'APh 17 abc'),
#  ('Ph 1 abc', 'APh 23'),
#  ('APh 23', 'APh 24'),
#  ('APh 17 abc', 'APh 105 abc'),
#  ('Ph 12 abc', 'APh 112 ab'),
#  ('ACM 95/100 ab', 'APh 112 ab'),
#  ('Ph 106 abc', 'APh 112 ab'),
#  ('Ph 125 abc', 'APh 114 abc'),
#  ('ACM 95/100 ab', 'APh 115'),
#  ('ACM 95/100 ab', 'APh 116'),
#  ('APh 115', 'APh 116'),
#  ('Ph 125 abc', 'APh 138 ab'),
#  ('Ph 127 ab', 'APh 138 ab'),
#  ('Ph 137 abc', 'APh 138 ab'),
#  ('Ph 106 abc', 'APh 156 abc'),
#  ('Ph 125 abc', 'APh 190 abc'),
#  ('Ph 125 abc', 'APh 256'),
#  ('APh 114 abc', 'APh 256'),
#  ('Ma 1 abc', 'Ay 20'),
#  ('Ph 1 abc', 'Ay 20'),
#  ('Ma 1 abc', 'Ay 21'),
#  ('Ph 1 abc', 'Ay 21'),
#  ('Ay 20', 'Ay 101'),
#  ('Ay 20', 'Ay 102'),
#  ('Ph 1 abc', 'Ay 104'),
#  ('Ph 2 abc', 'Ay 104'),
#  ('Ay 20', 'Ay 105'),
#  ('CS 1', 'Ay 107'),
#  ('Ph 106 abc', 'Ay 121'),
#  ('Ph 125 abc', 'Ay 121'),
#  ('Ph 106 abc', 'Ay 122 abc'),
#  ('Ay 101', 'Ay 123'),
#  ('Ph 125 abc', 'Ay 123'),
#  ('Ay 21', 'Ay 124'),
#  ('Ph 106 abc', 'Ay 124'),
#  ('Ph 106 abc', 'Ay 125'),
#  ('Ph 125 abc', 'Ay 125'),
#  ('Ay 102', 'Ay 126'),
#  ('Ay 21', 'Ay 127'),
#  ('Ph 106 abc', 'Ay 127'),
#  ('Ay 142', 'Ay 144'),
#  ('Ph 20', 'Ay 190'),
#  ('Ph 21', 'Ay 190'),
#  ('Ph 22', 'Ay 190'),
#  ('Ay 123', 'Ay 211'),
#  ('Ay 124', 'Ay 211'),
#  ('Ay 127', 'Ay 211'),
#  ('Ay 121', 'Ay 219'),
#  ('Ay 123', 'Ay 219'),
#  ('Ay 124', 'Ay 219'),
#  ('Ay 126', 'Ay 219'),
#  ('Ch 110', 'BMB 170'),
#  ('Ch 110', 'BMB 174'),
#  ('Ch 110', 'BMB 178'),
#  ('Ch 1 ab', 'BE 25'),
#  ('Ma 2/102', 'BE 25'),
#  ('Bi 1', 'BE 103 a'),
#  ('Bi 8', 'BE 103 a'),
#  ('Bi 1 x', 'BE 103 a'),
#  ('BE 103 a', 'BE 103 b'),
#  ('Ma 1 abc', 'BE 103 b'),
#  ('Ma 3/103', 'BE 103 b'),
#  ('Bi 195', 'BE 103 b'),
#  ('Bi 1', 'BE 150'),
#  ('Bi 8', 'BE 150'),
#  ('Ma 2/102', 'BE 150'),
#  ('Bi 195', 'BE 150'),
#  ('Bi 8', 'BE 153'),
#  ('Bi 9', 'BE 153'),
#  ('Bi 8', 'BE 159'),
#  ('Bi 9', 'BE 159'),
#  ('ACM 95/100 ab', 'BE 159'),
#  ('Ph 2 abc', 'BE 161'),
#  ('ACM 95/100 ab', 'BE 161'),
#  ('BE 103 a', 'BE 205'),
#  ('BE 103 b', 'BE 205'),
#  ('CMS 155', 'BE 205'),
#  ('Bi 8', 'Bi 9'),
#  ('Bi 8', 'Bi 10'),
#  ('Bi 22', 'Bi 90 abc'),
#  ('Bi 8', 'Bi 114'),
#  ('Bi 9', 'Bi 114'),
#  ('Bi 122', 'Bi 114'),
#  ('Ch 110', 'Bi 114'),
#  ('Bi 1', 'Bi 116'),
#  ('Bi 8', 'Bi 116'),
#  ('Bi 9', 'Bi 116'),
#  ('ESE 166', 'Bi 116'),
#  ('Bi 8', 'Bi 117'),
#  ('Bi 9', 'Bi 117'),
#  ('Bi 8', 'Bi 118'),
#  ('Bi 9', 'Bi 118'),
#  ('Bi 8', 'Bi 122'),
#  ('Bi 9', 'Bi 122'),
#  ('Bi 1', 'Bi 158'),
#  ('Bi 8', 'Bi 158'),
#  ('Bi 8', 'Bi 160'),
#  ('Bi 9', 'Bi 160'),
#  ('Bi 8', 'Bi 182'),
#  ('Bi 8', 'Bi 183'),
#  ('CS 2', 'Bi 183'),
#  ('Ma 3/103', 'Bi 183'),
#  ('BE 103 a', 'Bi 183'),
#  ('Bi 122', 'Bi 188'),
#  ('Bi 8', 'Bi 189'),
#  ('Bi 9', 'Bi 189'),
#  ('Bi 122', 'Bi 190'),
#  ('Ma 1 abc', 'Bi 192'),
#  ('Bi 8', 'Bi 192'),
#  ('CS 1', 'Bi 192'),
#  ('ACM 95/100 ab', 'Bi 192'),
#  ('Bi 9', 'Bi 222'),
#  ('Ch 110', 'Bi 222'),
#  ('Ch 111', 'Bi 222'),
#  ('Bi 177', 'Bi 227'),
#  ('Bi 1', 'Bi 250 b'),
#  ('Bi 8', 'Bi 250 b'),
#  ('Ma 2/102', 'Bi 250 b'),
#  ('Bi 195', 'Bi 250 b'),
#  ('Bi 8', 'Bi 145 a'),
#  ('Bi 9', 'Bi 145 a'),
#  ('Ch 110', 'Bi 145 a'),
#  ('ChE 15', 'ChE 62'),
#  ('Ma 2/102', 'ChE 62'),
#  ('ChE 62', 'ChE 101'),
#  ('ChE 63 ab', 'ChE 101'),
#  ('ACM 95/100 ab', 'ChE 103 abc'),
#  ('ChE 101', 'ChE 103 abc'),
#  ('ACM 95/100 ab', 'ChE 105'),
#  ('ChE 62', 'ChE 111'),
#  ('ChE 63 ab', 'ChE 111'),
#  ('ME 11 abc', 'ChE 111'),
#  ('Ph 2 abc', 'ChE 111'),
#  ('MS 115', 'ChE 111'),
#  ('Ch 21 abc', 'ChE 114'),
#  ('ChE 63 ab', 'ChE 115'),
#  ('ChE 103 abc', 'ChE 115'),
#  ('ChE 101', 'ChE 115'),
#  ('ChE 63 ab', 'ChE 118'),
#  ('ChE 101', 'ChE 118'),
#  ('ChE 103 abc', 'ChE 118'),
#  ('ChE 126', 'ChE 118'),
#  ('ChE 63 ab', 'ChE 120'),
#  ('ChE 101', 'ChE 120'),
#  ('ChE 103 abc', 'ChE 120'),
#  ('ChE 126', 'ChE 120'),
#  ('ChE 63 ab', 'ChE 126'),
#  ('ChE 101', 'ChE 126'),
#  ('ChE 103 abc', 'ChE 126'),
#  ('ChE 105', 'ChE 126'),
#  ('ChE 63 ab', 'ChE 128'),
#  ('ChE 101', 'ChE 128'),
#  ('ChE 103 abc', 'ChE 128'),
#  ('ChE 63 ab', 'ChE 130'),
#  ('ChE 101', 'ChE 130'),
#  ('ChE 15', 'ChE 141'),
#  ('ACM 104', 'ChE 141'),
#  ('ChE 141', 'ChE 142'),
#  ('ChE 101', 'ChE 152'),
#  ('Bi 8', 'ChE 163'),
#  ('Ch 110', 'ChE 163'),
#  ('CS 1', 'ChE 163'),
#  ('Ch 21 abc', 'ChE 164'),
#  ('ChE 63 ab', 'ChE 165'),
#  ('ACM 95/100 ab', 'ChE 174'),
#  ('ChE 151 ab', 'ChE 174'),
#  ('Ch 110', 'ChE 188'),
#  ('ChE 101', 'ChE 188'),
#  ('ACM 95/100 ab', 'ChE 188'),
#  ('Ch 1 ab', 'Ch 6 ab'),
#  ('Ch 4 ab', 'Ch 6 ab'),
#  ('Ch 1 ab', 'Ch 15'),
#  ('Ch 3', 'Ch 15'),
#  ('Ch 3 x', 'Ch 15'),
#  ('Ch 14', 'Ch 15'),
#  ('Ch 1 ab', 'Ch 21 abc'),
#  ('Ph 2 abc', 'Ch 21 abc'),
#  ('Ph 12 abc', 'Ch 21 abc'),
#  ('Ma 2/102', 'Ch 21 abc'),
#  ('Ma 3/103', 'Ch 21 abc'),
#  ('Ch 1 ab', 'Ch 25'),
#  ('Ph 2 abc', 'Ch 25'),
#  ('Ph 12 abc', 'Ch 25'),
#  ('Ma 2/102', 'Ch 25'),
#  ('Ch 21 abc', 'Ch 25'),
#  ('Ch 1 ab', 'Ch 41 abc'),
#  ('Ch 41 abc', 'Ch 102'),
#  ('Ch 41 abc', 'Ch 104'),
#  ('Ch 41 abc', 'Ch 110'),
#  ('Ch 110', 'Ch 111'),
#  ('Bi 8', 'Ch 111'),
#  ('Bi 122', 'Ch 111'),
#  ('Ch 102', 'Ch 112'),
#  ('Ch 21 abc', 'Ch 121 ab'),
#  ('Ch 125 ab', 'Ch 121 ab'),
#  ('Ch 21 abc', 'Ch 122'),
#  ('Ch 21 abc', 'Ch 125 ab'),
#  ('Ch 21 abc', 'Ch 129'),
#  ('Ch 125 ab', 'Ch 129'),
#  ('Ch 21 abc', 'Ch 135'),
#  ('Ch 41 abc', 'Ch 135'),
#  ('APh 9 ab', 'Ch 140 ab'),
#  ('Ch 41 abc', 'Ch 143'),
#  ('Ch 41 abc', 'Ch 145'),
#  ('Ch 110', 'Ch 145'),
#  ('Ch 41 abc', 'Ch 146'),
#  ('Ch 41 abc', 'Ch 147'),
#  ('Ch 41 abc', 'Ch 149'),
#  ('Ch 112', 'Ch 153 abc'),
#  ('Ch 21 abc', 'Ch 153 abc'),
#  ('Ch 112', 'Ch 154 ab'),
#  ('Ch 112', 'Ch 212'),
#  ('Ch 110', 'Ch 212'),
#  ('Ch 21 abc', 'Ch 213 abc'),
#  ('Ch 125 ab', 'Ch 225'),
#  ('Ch 125 ab', 'Ch 226'),
#  ('Ch 41 abc', 'Ch 242 ab'),
#  ('Ch 41 abc', 'Ch 247'),
#  ('Ch 242 ab', 'Ch 247'),
#  ('Ch 145', 'Ch 251'),
#  ('Ch 146', 'Ch 251'),
#  ('Ch 1 ab', 'Ch 4 ab'),
#  ('Ch 3', 'Ch 4 ab'),
#  ('Ch 3 x', 'Ch 4 ab'),
#  ('Ch 4 ab', 'Ch 5 ab'),
#  ('Ch 102', 'Ch 5 ab'),
#  ('Ch 1 ab', 'Ch 8'),
#  ('Ch 3', 'Ch 8'),
#  ('Ch 3 x', 'Ch 8'),
#  ('Ch 41 abc', 'Ch 8'),
#  ('Ch 1 ab', 'Ch 9'),
#  ('Ch 3', 'Ch 9'),
#  ('Ch 3 x', 'Ch 9'),
#  ('Ch 41 abc', 'Ch 9'),
#  ('Ch 21 abc', 'Ch 120 ab'),
#  ('Ch 41 abc', 'Ch 144 ab'),
#  ('Ch 21 abc', 'Ch 144 ab'),
#  ('Ae 102 abc', 'CE 108 ab'),
#  ('Ae 160 ab', 'CE 108 ab'),
#  ('ME 11 abc', 'CE 112 ab'),
#  ('ME 12 abc', 'CE 112 ab'),
#  ('ACM 95/100 ab', 'CE 112 ab'),
#  ('Ae 160 ab', 'CE 173'),
#  ('AM 151', 'CE 180'),
#  ('Ae 102 abc', 'CE 108'),
#  ('Ae 160 ab', 'CE 108'),
#  ('NB 150', 'CNS 102 ab'),
#  ('CNS 187', 'CNS 102 ab'),
#  ('NB 150', 'CNS 187'),
#  ('Bi 195', 'CNS 187'),
#  ('NB 150', 'CNS 247'),
#  ('CS 2', 'CS 3'),
#  ('CS 1', 'CS 4'),
#  ('CS 1', 'CS 11'),
#  ('CS 1', 'CS 12'),
#  ('CS 2', 'CS 21'),
#  ('CS 2', 'CS 22'),
#  ('CS 2', 'CS 24'),
#  ('CS 3', 'CS 24'),
#  ('CS 2', 'CS 38'),
#  ('Ma 6/106 abc', 'CS 38'),
#  ('Ma 121 ab', 'CS 38'),
#  ('CS 21', 'CS 38'),
#  ('CS 21', 'CS 101'),
#  ('CS 38', 'CS 101'),
#  ('CS 1', 'CS 111'),
#  ('CS 1', 'CS 115'),
#  ('CS 4', 'CS 115'),
#  ('CS 1', 'CS 116'),
#  ('Ma 1 abc', 'CS 120'),
#  ('Ph 2 abc', 'CS 120'),
#  ('CS 21', 'CS 120'),
#  ('CS 38', 'CS 120'),
#  ('CS 1', 'CS 121'),
#  ('CS 2', 'CS 122'),
#  ('CS 38', 'CS 122'),
#  ('CS 121', 'CS 122'),
#  ('CS 121', 'CS 123'),
#  ('CS 122', 'CS 123'),
#  ('CS 24', 'CS 124'),
#  ('CS 2', 'CS 130'),
#  ('CS 1', 'CS 132'),
#  ('CS 24', 'CS 137'),
#  ('CS 142', 'CS 141'),
#  ('CS 143', 'CS 141'),
#  ('CMS 144', 'CS 141'),
#  ('Ma 2/102', 'CS 143'),
#  ('Ma 3/103', 'CS 143'),
#  ('CS 24', 'CS 143'),
#  ('CS 38', 'CS 143'),
#  ('CMS 144', 'CS 145'),
#  ('CS 142', 'CS 145'),
#  ('Ma 2/102', 'CS 146'),
#  ('Ma 3/103', 'CS 146'),
#  ('CS 21', 'CS 151'),
#  ('CS 38', 'CS 151'),
#  ('Ma 1 abc', 'CS 152'),
#  ('CS 21', 'CS 152'),
#  ('CS 38', 'CS 152'),
#  ('CS 21', 'CS 153'),
#  ('CS 38', 'CS 153'),
#  ('CS 2', 'CS 156 ab'),
#  ('Ma 2/102', 'CS 156 ab'),
#  ('CMS 155', 'CS 159'),
#  ('CMS 122', 'CS 165'),
#  ('ACM 116', 'CS 165'),
#  ('CS 156 ab', 'CS 165'),
#  ('IDS 157', 'CS 165'),
#  ('ACM 104', 'CS 166'),
#  ('CMS 107', 'CS 166'),
#  ('CS 2', 'CS 171'),
#  ('Ma 1 abc', 'CS 171'),
#  ('CS 171', 'CS 174'),
#  ('CS 2', 'CS 178'),
#  ('CS 1', 'CS 2'),
#  ('CS 4', 'CS 131'),
#  ('CS 24', 'CS 142'),
#  ('CS 38', 'CS 142'),
#  ('CS 38', 'CS 150 ab'),
#  ('Ma 5/105 abc', 'CS 150 ab'),
#  ('CS 38', 'CS 162'),
#  ('CMS 155', 'CS 162'),
#  ('CS 156 ab', 'CS 162'),
#  ('CS 171', 'CS 176'),
#  ('CS 174', 'CS 176'),
#  ('ACM 104', 'CMS 107'),
#  ('Ma 1 abc', 'CMS 107'),
#  ('ACM 104', 'CMS 117'),
#  ('ACM 116', 'CMS 117'),
#  ('ACM 11', 'CMS 122'),
#  ('ACM 104', 'CMS 122'),
#  ('Ma 2/102', 'CMS 139'),
#  ('Ma 3/103', 'CMS 139'),
#  ('Ma 6/106 abc', 'CMS 139'),
#  ('CS 21', 'CMS 139'),
#  ('CS 38', 'CMS 139'),
#  ('ACM 116', 'CMS 139'),
#  ('CMS 122', 'CMS 139'),
#  ('Ma 2/102', 'CMS 144'),
#  ('Ma 3/103', 'CMS 144'),
#  ('Ma 6/106 abc', 'CMS 144'),
#  ('CS 21', 'CMS 144'),
#  ('CS 38', 'CMS 144'),
#  ('CS 156 ab', 'CMS 155'),
#  ('CDS 110', 'CDS 90 abc'),
#  ('CDS 112', 'CDS 90 abc'),
#  ('Ma 1 abc', 'CDS 110'),
#  ('Ma 2/102', 'CDS 110'),
#  ('CDS 110', 'CDS 112'),
#  ('CDS 131', 'CDS 112'),
#  ('Ma 1 abc', 'CDS 131'),
#  ('Ma 2/102', 'CDS 131'),
#  ('ACM 104', 'CDS 131'),
#  ('CDS 110', 'CDS 190'),
#  ('CMS 107', 'CDS 231'),
#  ('CMS 122', 'CDS 231'),
#  ('CDS 131', 'CDS 231'),
#  ('CMS 107', 'CDS 232'),
#  ('CDS 231', 'CDS 232'),
#  ('CDS 231', 'CDS 233'),
#  ('CDS 232', 'CDS 233'),
#  ('CDS 231', 'CDS 242'),
#  ('CDS 232', 'CDS 242'),
#  ('CDS 231', 'CDS 243'),
#  ('CDS 232', 'CDS 243'),
#  ('CDS 231', 'CDS 244'),
#  ('CDS 232', 'CDS 244'),
#  ('Ph 1 abc', 'EE 44'),
#  ('EE 44', 'EE 45'),
#  ('Ma 1 abc', 'EE 55'),
#  ('EE 45', 'EE 85'),
#  ('EE 40', 'EE 90'),
#  ('EE 45', 'EE 90'),
#  ('EE 45', 'EE 91'),
#  ('Ma 1 abc', 'EE 111'),
#  ('EE 111', 'EE 112'),
#  ('Ma 3/103', 'EE 112'),
#  ('EE 45', 'EE 113'),
#  ('EE 44', 'EE 114 ab'),
#  ('Ph 1 abc', 'EE 115'),
#  ('EE 10 ab', 'EE 119 abc'),
#  ('CS 24', 'EE 119 abc'),
#  ('EE 111', 'EE 121'),
#  ('ACM 116', 'EE 121'),
#  ('ACM 104', 'EE 121'),
#  ('EE 10 ab', 'EE 125'),
#  ('Ma 3/103', 'EE 126 ab'),
#  ('EE 55', 'EE 127'),
#  ('Ma 3/103', 'EE 127'),
#  ('EE 111', 'EE 128 ab'),
#  ('EE 160', 'EE 128 ab'),
#  ('EE 112', 'EE 128 ab'),
#  ('APh 130', 'EE 131'),
#  ('EE 44', 'EE 135'),
#  ('Ma 2/102', 'EE 135'),
#  ('Ma 3/103', 'EE 136'),
#  ('ACM 116', 'EE 136'),
#  ('CMS 117', 'EE 136'),
#  ('Ma 140 ab', 'EE 136'),
#  ('EE 45', 'EE 151'),
#  ('EE 45', 'EE 153'),
#  ('Ph 2 abc', 'EE 157 ab'),
#  ('EE 151', 'EE 158'),
#  ('Ph 125 abc', 'EE 158'),
#  ('ACM 104', 'EE 161'),
#  ('ACM 116', 'EE 161'),
#  ('EE 111', 'EE 163'),
#  ('ACM 116', 'EE 163'),
#  ('ACM 116', 'EE 164'),
#  ('ACM 116', 'EE 167'),
#  ('Ma 3/103', 'EE 167'),
#  ('APh 9 ab', 'EE 185'),
#  ('APh 9 ab', 'EE 187'),
#  ('EE 180', 'EE 187'),
#  ('EE 45', 'EE 124'),
#  ('EE 45', 'EE 152'),
#  ('EE 153', 'EE 152'),
#  ('ESE 90', 'ESE 91'),
#  ('ESE 101', 'ESE 130'),
#  ('ESE 102', 'ESE 130'),
#  ('Ma 2/102', 'ESE 130'),
#  ('ESE 102', 'ESE 131'),
#  ('ESE 130', 'ESE 131'),
#  ('ESE 101', 'ESE 132'),
#  ('ESE 130', 'ESE 132'),
#  ('ESE 101', 'ESE 133'),
#  ('ESE 130', 'ESE 133'),
#  ('ESE 101', 'ESE 134'),
#  ('ESE 101', 'ESE 135'),
#  ('ESE 102', 'ESE 135'),
#  ('ESE 101', 'ESE 136'),
#  ('ESE 102', 'ESE 136'),
#  ('ESE 131', 'ESE 137'),
#  ('ESE 131', 'ESE 138'),
#  ('Ch 1 ab', 'ESE 142'),
#  ('ESE 101', 'ESE 156'),
#  ('ESE 142', 'ESE 168'),
#  ('ESE 166', 'ESE 168'),
#  ('Ch 1 ab', 'ESE 171'),
#  ('ESE 171', 'ESE 172'),
#  ('Ch 41 abc', 'ESE 176'),
#  ('ESE 176', 'ESE 177'),
#  ('Ch 1 ab', 'Ge 11 b'),
#  ('Ma 1 abc', 'Ge 11 c'),
#  ('Ph 1 abc', 'Ge 11 c'),
#  ('Ch 1 ab', 'Ge 11 d'),
#  ('Ma 2/102', 'Ge 11 d'),
#  ('Ph 2 abc', 'Ge 11 d'),
#  ('Ma 2/102', 'Ge 102'),
#  ('Ph 2 abc', 'Ge 102'),
#  ('Ge 108', 'Ge 102'),
#  ('Ge 11 a', 'Ge 106'),
#  ('Ge 11 b', 'Ge 106'),
#  ('Ph 2 abc', 'Ge 108'),
#  ('Ma 2/102', 'Ge 108'),
#  ('Ge 11 a', 'Ge 112'),
#  ('Ge 11 b', 'Ge 112'),
#  ('Ge 114 a', 'Ge 114 b'),
#  ('Ge 114 a', 'Ge 115 a'),
#  ('Ge 114 b', 'Ge 115 a'),
#  ('Ge 114 a', 'Ge 115 b'),
#  ('Ge 114 b', 'Ge 115 b'),
#  ('Ge 114 a', 'Ge 115 c'),
#  ('Ge 114 b', 'Ge 115 c'),
#  ('Ge 115 a', 'Ge 115 c'),
#  ('Ge 115 b', 'Ge 115 c'),
#  ('Ge 114 a', 'Ge 116'),
#  ('CS 1', 'Ge 117'),
#  ('Ma 1 abc', 'Ge 118'),
#  ('Ge 11 a', 'Ge 120 a'),
#  ('Ge 11 b', 'Ge 120 a'),
#  ('Ge 106', 'Ge 120 a'),
#  ('Ge 120 a', 'Ge 120 b'),
#  ('Ge 120 a', 'Ge 121 abc'),
#  ('Ge 120 b', 'Ge 121 abc'),
#  ('Ge 11 a', 'Ge 122 abc'),
#  ('Ge 11 b', 'Ge 122 abc'),
#  ('Ge 101', 'Ge 122 abc'),
#  ('Ge 11 a', 'Ge 124 b'),
#  ('Ge 11 b', 'Ge 124 b'),
#  ('Ge 11 a', 'Ge 125'),
#  ('Ge 11 a', 'Ge 136 abc'),
#  ('Ge 11 b', 'Ge 136 abc'),
#  ('Ge 101', 'Ge 136 abc'),
#  ('Ph 106 abc', 'Ge 137'),
#  ('ACM 95/100 ab', 'Ge 137'),
#  ('Ma 2/102', 'Ge 139'),
#  ('Ph 2 abc', 'Ge 139'),
#  ('Ge 140 a', 'Ge 140 c'),
#  ('Ch 41 abc', 'Ge 143'),
#  ('ESE 102', 'Ge 149'),
#  ('Ch 1 ab', 'Ge 150'),
#  ('Ma 2/102', 'Ge 150'),
#  ('Ph 2 abc', 'Ge 150'),
#  ('ESE 102', 'Ge 155'),
#  ('Ge 11 a', 'Ge 161'),
#  ('Ge 11 b', 'Ge 161'),
#  ('ACM 95/100 ab', 'Ge 162'),
#  ('Ae 160 ab', 'Ge 163'),
#  ('Ge 11 a', 'Ge 164'),
#  ('Ge 11 d', 'Ge 164'),
#  ('Ma 1 abc', 'Ge 166'),
#  ('Ge 112', 'Ge 177'),
#  ('Ge 106', 'Ge 177'),
#  ('ESE 166', 'Ge 178'),
#  ('ESE 168', 'Ge 178'),
#  ('Ch 21 abc', 'Ge 212'),
#  ('Ge 115 a', 'Ge 212'),
#  ('Ge 114 a', 'Ge 214'),
#  ('Ch 21 abc', 'Ge 214'),
#  ('Ge 115 a', 'Ge 215'),
#  ('Ge 115 b', 'Ge 215'),
#  ('Ge 140 b', 'Ge 217'),
#  ('Ge 140 a', 'Ge 218'),
#  ('Ge 140 b', 'Ge 218'),
#  ('Ge 140 c', 'Ge 218'),
#  ('Ge 140 a', 'Ge 219'),
#  ('Ge 140 b', 'Ge 219'),
#  ('Ge 118', 'Ge 264'),
#  ('ACM 95/100 ab', 'Ge 270'),
#  ('CMS 122', 'Ge 270'),
#  ('Ge 11 a', 'Ge 270'),
#  ('Ge 11 b', 'Ge 270'),
#  ('Ge 106', 'Ge 270'),
#  ('Ge 162', 'Ge 270'),
#  ('Ge 161', 'Ge 270'),
#  ('Ma 3/103', 'IDS 126'),
#  ('ACM 116', 'IDS 126'),
#  ('IDS 157', 'IDS 126'),
#  ('ACM 116', 'IDS 157'),
#  ('Ma 3/103', 'IDS 157'),
#  ('Ma 3/103', 'IDS 158'),
#  ('ACM 116', 'IDS 158'),
#  ('IDS 157', 'IDS 158'),
#  ('MS 115', 'MS 90'),
#  ('Ph 2 abc', 'MS 115'),
#  ('MS 115', 'MS 121'),
#  ('MS 132', 'MS 122'),
#  ('MS 122', 'MS 125'),
#  ('APh 105 abc', 'MS 133'),
#  ('ChE 164', 'MS 133'),
#  ('MS 115', 'MS 161'),
#  ('APh 114 abc', 'MS 162'),
#  ('MS 115', 'MS 166'),
#  ('MS 116', 'MS 166'),
#  ('EE 131', 'MS 171'),
#  ('MS 132', 'MS 171'),
#  ('Ma 1 abc', 'Ma 2/102'),
#  ('Ma 1 abc', 'Ma 3/103'),
#  ('Ma 2/102', 'Ma 109 abc'),
#  ('Ma 108 abc', 'Ma 109 abc'),
#  ('Ma 108 abc', 'Ma 110 abc'),
#  ('Ma 110 abc', 'Ma 111 abc'),
#  ('Ma 3/103', 'Ma 112 ab'),
#  ('Ma 5/105 abc', 'Ma 116 abc'),
#  ('Ma 5/105 abc', 'Ma 117 abc'),
#  ('Ma 5/105 abc', 'Ma 118'),
#  ('Ma 5/105 abc', 'Ma 120 abc'),
#  ('Ma 5/105 abc', 'Ma 121 ab'),
#  ('Ma 5/105 abc', 'Ma 123'),
#  ('Ma 5/105 abc', 'Ma 124'),
#  ('Ma 5/105 abc', 'Ma 125'),
#  ('Ma 120 abc', 'Ma 128'),
#  ('Ma 120 abc', 'Ma 130 abc'),
#  ('Ma 130 abc', 'Ma 132 abc'),
#  ('Ma 130 abc', 'Ma 135 ab'),
#  ('Ma 108 abc', 'Ma 140 ab'),
#  ('Ma 108 abc', 'Ma 142 ab'),
#  ('Ma 109 abc', 'Ma 142 ab'),
#  ('Ma 5/105 abc', 'Ma 145 abc'),
#  ('Ma 108 abc', 'Ma 147 abc'),
#  ('Ma 109 abc', 'Ma 147 abc'),
#  ('Ma 109 abc', 'Ma 151 abc'),
#  ('Ma 151 abc', 'Ma 157 abc'),
#  ('Ma 5/105 abc', 'Ma 160 abc'),
#  ('Ma 160 abc', 'Ma 162 ab'),
#  ('ME 12 abc', 'ME 14'),
#  ('ME 13/113', 'ME 14'),
#  ('ME 13/113', 'ME 23/123'),
#  ('Ma 1 abc', 'ME 40'),
#  ('ME 11 abc', 'ME 50 ab'),
#  ('ME 12 abc', 'ME 50 ab'),
#  ('ME 13/113', 'ME 50 ab'),
#  ('ME 14', 'ME 50 ab'),
#  ('ACM 11', 'ME 50 ab'),
#  ('ME 14', 'ME 72 ab'),
#  ('Ma 2/102', 'ME 115 ab'),
#  ('ACM 95/100 ab', 'ME 115 ab'),
#  ('Ph 1 abc', 'ME 117'),
#  ('Ch 1 ab', 'ME 117'),
#  ('Ma 1 abc', 'ME 117'),
#  ('ME 11 abc', 'ME 119'),
#  ('ME 12 abc', 'ME 119'),
#  ('ACM 95/100 ab', 'ME 119'),
#  ('ME 129', 'ME 133 abc'),
#  ('ME 11 abc', 'ME 146'),
#  ('ME 12 abc', 'ME 146'),
#  ('ACM 95/100 ab', 'ME 146'),
#  ('ACM 106 ab', 'ME 146'),
#  ('Ae 160 ab', 'ME 163'),
#  ('ME 133 abc', 'ME 169'),
#  ('Ae 160 ab', 'ME 174'),
#  ('ACM 95/100 ab', 'ME 202 abc'),
#  ('Ae 101 abc', 'ME 202 abc'),
#  ('MS 115', 'ME 224'),
#  ('Ae 102 abc', 'ME 224'),
#  ('APh 105 abc', 'ME 224'),
#  ('ME 133 abc', 'ME 234 ab'),
#  ('ACM 95/100 ab', 'ME 260'),
#  ('Ae 102 abc', 'ME 260'),
#  ('Ae 160 ab', 'ME 260'),
#  ('Ae 102 abc', 'ME 266 ab'),
#  ('Ae 160 ab', 'ME 266 ab'),
#  ('ME 129', 'ME 134'),
#  ('Ae 101 abc', 'MedE 243'),
#  ('ChE 103 abc', 'MedE 243'),
#  ('Bi 8', 'NB 150'),
#  ('Bi 9', 'NB 150'),
#  ('NB 150', 'NB 152'),
#  ('NB 150', 'NB 154'),
#  ('NB 150', 'NB 155'),
#  ('NB 150', 'NB 162'),
#  ('NB 150', 'NB 163'),
#  ('NB 150', 'NB 164'),
#  ('NB 150', 'NB 220'),
#  ('Ph 1 abc', 'Ph 2 abc'),
#  ('Ma 1 abc', 'Ph 2 abc'),
#  ('Ph 1 abc', 'Ph 3'),
#  ('Ph 1 abc', 'Ph 5'),
#  ('Ma 1 abc', 'Ph 5'),
#  ('Ma 2/102', 'Ph 5'),
#  ('Ph 2 abc', 'Ph 6'),
#  ('Ph 12 abc', 'Ph 6'),
#  ('Ma 2/102', 'Ph 6'),
#  ('Ma 3/103', 'Ph 6'),
#  ('Ph 3', 'Ph 6'),
#  ('Ph 6', 'Ph 7'),
#  ('Ph 2 abc', 'Ph 7'),
#  ('Ph 12 abc', 'Ph 7'),
#  ('Ph 1 abc', 'Ph 8 bc'),
#  ('Ph 1 abc', 'Ph 12 abc'),
#  ('Ma 1 abc', 'Ph 12 abc'),
#  ('CS 1', 'Ph 20'),
#  ('Ph 20', 'Ph 21'),
#  ('Ph 20', 'Ph 22'),
#  ('Ph 1 abc', 'Ph 50 ab'),
#  ('Ph 7', 'Ph 77 abc'),
#  ('Ph 1 abc', 'Ph 105'),
#  ('Ma 2/102', 'Ph 105'),
#  ('Ph 2 abc', 'Ph 106 abc'),
#  ('Ph 12 abc', 'Ph 106 abc'),
#  ('Ma 2/102', 'Ph 106 abc'),
#  ('Ph 127 ab', 'Ph 118 ab'),
#  ('APh 105 abc', 'Ph 118 ab'),
#  ('Ma 2/102', 'Ph 125 abc'),
#  ('Ph 12 abc', 'Ph 125 abc'),
#  ('Ph 2 abc', 'Ph 125 abc'),
#  ('Ph 12 abc', 'Ph 127 ab'),
#  ('Ph 125 abc', 'Ph 127 ab'),
#  ('Ma 2/102', 'Ph 129 abc'),
#  ('Ph 2 abc', 'Ph 129 abc'),
#  ('Ph 125 abc', 'Ph 135'),
#  ('Ph 106 abc', 'Ph 136 abc'),
#  ('Ph 125 abc', 'Ph 137 abc'),
#  ('Ph 125 abc', 'Ph 139'),
#  ('Ph 6', 'Ph 177'),
#  ('Ph 106 abc', 'Ph 177'),
#  ('Ph 125 abc', 'Ph 177'),
#  ('Ph 125 abc', 'Ph 199'),
#  ('Ph 106 abc', 'Ph 199'),
#  ('Ph 125 abc', 'Ph 203'),
#  ('Ph 125 abc', 'Ph 205 abc'),
#  ('Ph 125 abc', 'Ph 219 abc'),
#  ('Ph 135', 'Ph 223 ab'),
#  ('Ph 129 abc', 'Ph 229 abc'),
#  ('Ph 205 abc', 'Ph 230 abc'),
#  ('Ph 205 abc', 'Ph 232'),
#  ('Ph 236 abc', 'Ph 235 ab'),
#  ('Ph 205 abc', 'Ph 235 ab'),
#  ('Ph 106 abc', 'Ph 237'),
#  ('Ph 12 abc', 'Ph 237'),
#  ('Ph 205 abc', 'Ph 250')]

# %%
G_caltech = nx.DiGraph()
G_caltech.add_nodes_from(Caltech_node_list)
G_caltech.add_edges_from(Caltech_edge_list)
nx.is_directed_acyclic_graph(G_caltech)
# Out:
# True

# %% [markdown]
# ## Cyprus University of Technology (CUT)

# %%
CUT_nodes = []
CUT_edges = []
with open("CUT_Courses.txt", encoding='utf-8') as f:
  contents = [line for line in f.readlines() if line != '\n']
  dlt = 'Pre Req. '
  for line in contents:
    clean = line.replace(dlt, '')
    brk = clean.split(' ', 1)
    postreq = brk[0].strip('\n')
    CUT_nodes.append(postreq)
    if len(brk) != 1:
      prereq = brk[1].strip('\n')
    pre = prereq.replace('(','').replace(')','')
    prereqs = []
    if ',' in pre:
      prereqs = pre.split(', ', 1)
    else:
      prereqs = [pre]
    for p in prereqs:
      CUT_edges.append((p, postreq))
  f.close()

G_CUT = nx.DiGraph()
G_CUT.add_nodes_from(CUT_nodes)
G_CUT.add_edges_from(CUT_edges)
nx.is_directed_acyclic_graph(G_CUT)
# Out:
# True

# %% [markdown]
# # Johns Hopkins University (JHU)

# %%
JH_data = pd.read_csv("JHU_Courses.csv")
JH_data["Pre Req"] = JH_data["Pre Req"].fillna("")
JH_data.dropna(subset=["Course"], inplace=True)
JH_data
# Out:
#            Course             Department Name  \
# 0      AS.440.011       AAP Applied Economics
# 1      AS.440.304       AAP Applied Economics
# 2      AS.440.601       AAP Applied Economics
# 3      AS.440.602       AAP Applied Economics
# 4      AS.440.605       AAP Applied Economics
# ...           ...                         ...
# 10081  SA.743.233  SN International Economics
# 10082  SA.745.316   SN International Politics
# 10083  SA.740.001              SN M.A. Thesis
# 10084  SA.747.401              SN M.A. Thesis
# 10085  SA.747.402              SN M.A. Thesis
#
#                                       Title  \
# 0              Forecasting in Organizations
# 1               Math Methods for Economists
# 2                      Microeconomic Theory
# 3                      Macroeconomic Theory
# 4                                Statistics
# ...                                     ...
# 10081                              Strategy
# 10082  The Making of Chinese Foreign Policy
# 10083                 MAIS Thesis Extension
# 10084         Independent Thesis Research I
# 10085        Independent Thesis Research II
#
#                                                  Pre Req
# 0      You must enroll in AS.440.615 AND one of the f...
# 1
# 2
# 3
# 4
# ...                                                  ...
# 10081
# 10082
# 10083
# 10084
# 10085
#
# [10086 rows x 4 columns]

# %%
JH_nodes = JH_data["Course"].to_list()
JH_edges = []
expr = r"\w\w\.\d\d\d\.\d\d\d"
for i in range(len(JH_nodes)):
  prereqs = JH_data["Pre Req"][i]
  if prereqs != "":
    course = JH_nodes[i]
    pre_list = re.findall(expr, prereqs)
    if pre_list != []:
      for pre in pre_list:
        if pre != course:
          JH_edges.append((pre, course))

G_JH = nx.DiGraph()
G_JH.add_nodes_from(JH_nodes)
G_JH.add_edges_from(JH_edges)
nx.is_directed_acyclic_graph(G_JH)
# Out:
# True
